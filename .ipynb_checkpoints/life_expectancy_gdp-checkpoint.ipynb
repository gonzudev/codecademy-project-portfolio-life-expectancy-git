# %% [markdown]
# # Life expectancy and GDP, 2000-2015
# ## Scope
# ### Goals of the project
# This report will find the statistical correlation, if any, between life expectancy and GDP in 6 countries around the world (Chile, China, Germany, Mexico, United States of America and Zimbabwe.
# ### Data gathering
# ### Analytical steps
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('all_data.csv')
print(df.head(10))
print(df.Country.unique())
print(df.Year.unique())
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10
# 5   Chile  2005                              78.4  1.229650e+11
# 6   Chile  2006                              78.9  1.547880e+11
# 7   Chile  2007                              78.9  1.736060e+11
# 8   Chile  2008                              79.6  1.796380e+11
# 9   Chile  2009                              79.3  1.723890e+11
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]

# %%
df = df.rename({'Life expectancy at birth (years)': 'LEABY'}, axis='columns')
print(df.head())
# Out:
#   Country  Year  LEABY           GDP
# 0   Chile  2000   77.3  7.786093e+10
# 1   Chile  2001   77.3  7.097992e+10
# 2   Chile  2002   77.8  6.973681e+10
# 3   Chile  2003   77.9  7.564346e+10
# 4   Chile  2004   78.0  9.921039e+10

# %%
sns.lineplot(x='Year', y='LEABY', hue='Country', data=df)
plt.show()
plt.clf()

# %%
sns.lineplot(x='Year', y='GDP', hue='Country', data=df)
plt.show()
plt.clf()

# %%
sns.scatterplot(x='LEABY', y='GDP', hue='Country', data=df)
plt.show()
plt.clf()

# %%
sns.barplot(x='Year', y='LEABY', data=df)
plt.show()
plt.clf()
